# %%
import tiktoken
import pinecone


class CodeAGI(object):
    
    def load_from_github(self, clone_url: str, file_type_list: list):
        raise NotImplementedError
    
    def load_from_directory(self, directory: str, file_type_list: list):
        raise NotImplementedError
        
    def start(self, prompt):
        pass
    
    def build_task_list(self):
        pass

# %%
import openai
import json
import tiktoken

from envs import env


class CodeBuilder:
    def __init__(self, api_key):
        openai.api_key = api_key

    def query_gpt3(self, prompt, max_tokens=255):
        
        response = openai.Completion.create(
            engine="text-davinci-003",
            prompt=prompt,
            max_tokens=max_tokens,
            n=1,
            stop=None,
            temperature=0.5,
        )

        return json.loads(response.choices[0].text.strip())

    def build_plan_and_task_list(self, build_prompt):
        prompt = f"Given the prompt to build something with code: '{build_prompt}', create a plan and a task list using GPT-3 in JSON format. Use the following JSON template: {{\"plan_list\": [{{\"title\": \"Research Django\", \"action_type\": \"google-search\", \"search_term\": \"Django documentation\"}}], \"task_list\": [{{\"title\": \"Create Poetry Project\", \"action_type\": \"execute_command\", \"command\": \"poetry init\"}}]}}:"
        enc = tiktoken.get_encoding("cl100k_base")
        prompt_token_count = len(enc.encode(prompt))
        print(prompt_token_count)
        max_allowed_tokens = 3500 - prompt_token_count
        print(max_allowed_tokens)
        plan_and_task_list_json = self.query_gpt3(prompt, max_tokens=max_allowed_tokens)
        return plan_and_task_list_json
    
    
# Replace "your_openai_api_key" with your actual OpenAI API key
code_builder = CodeBuilder(env('OPENAI_API_KEY'))

build_prompt = "Create a Flask based SaaS for Dealer Management System using Fauna DB, Fauna GraphQL, HTMX. TailwindCSS, Poetry and Jinja2."
plan_and_task_list = code_builder.build_plan_and_task_list(build_prompt)

print("Plan and Task List:")
print("--------------------")
plan_and_task_list

# %%
import requests
from bs4 import BeautifulSoup

docs_url = 'https://docs.bunny.net/reference/bunnynet-api-overview'
links = BeautifulSoup(requests.get(url).content, 'html.parser').body.find_all('a')

# %%
len(links)

# %%
def chunk_text(text, limit): 
    chunked_text = [] 
    current_chunk = "" 
    for word in text.split(): 
        current_chunk += word + " " 
        if len(current_chunk) > limit: 
            chunked_text.append(current_chunk) 
            current_chunk = "" 
    if current_chunk != "": 
        chunked_text.append(current_chunk) 
    return chunked_text 

def chunk_tag_list(links_list, max_size):
    final_links_list = []
    link_href_list = []
    for link in links_list:
        if not isinstance(link, str):
            if link.attrs['href'] not in link_href_list:
                link_href_list.append(link.attrs['href'])
                final_links_list.append(str(link))
    enc = tiktoken.get_encoding("cl100k_base")
    result_list = []
    tag_list = ""
    for link in final_links_list:
        link_str = f"{link},"
        if len(enc.encode(tag_list + link_str)) < max_size:
            tag_list += link_str
        else:
            result_list.append(tag_list)
            tag_list = link_str

    result_list.append(tag_list)
    return result_list

len(chunk_tag_list(links, 800))

# %%
import openai
import json
import tiktoken
import requests
from urllib.parse import urlparse 


from typing import Any

goal = 'create an Python SDK for the bunny.net API'

crawl_prompt_template = """
        Given the following list of links return the URLs that will help the most 
        while researching to achieve the goal to "{goal}".
        If the link is a relative URL ("/some/relative-link") convert it to an absolute URL 
        ("{hostname}/some/relative-link") using this hostname: {hostname}.
        Make sure to output valid JSON using the following JSON template for your output [{{"link": "http://example.com"}}]:
        {body}
        """

summary_prompt_template = """
            {hostname}Goal: {goal}
            Given the body of the page return the summary (with minimal text) and relevant code snippets
            from the page using the following JSON template 
            {{ "summary": "The summary of the page" , "relevant_code_snippets": ["The code snippet"] }}:
            {body}
            """
    
    
def get_result(goal: str, body: Any, prompt_template: str, url: str = ''):
    result_list = []
    enc = tiktoken.get_encoding("cl100k_base")
    up = urlparse(url)
    hostname = f"{up.scheme}://{up.hostname}"
    if isinstance(body, list):
        body_str_list = [str(i) for i in body]
        prompt_token_count = len(",".join(body_str_list))
        chunked_list = chunk_tag_list(body, 800)
        
    else:
        chunked_list = chunk_text(body, 800)
    no = 1
    for i in chunked_list:
        prompt = prompt_template.format(goal=goal, body=i, hostname=hostname)
        print(prompt)
        prompt_token_count = len(enc.encode(prompt))

        max_allowed_tokens = 3500 - prompt_token_count
        try:
            print(f'#{no} Request Made to OpenAI')
            no += 1
            response = openai.Completion.create(
                    engine="text-davinci-003",
                    prompt=prompt,
                    max_tokens=max_allowed_tokens,
                    n=1,
                    stop=None,
                    temperature=0.2,
                )
            
            result_list.extend(json.loads(response.choices[0].text))
        except (ConnectionResetError, requests.ConnectionError, json.JSONDecodeError):
            response = openai.Completion.create(
                    engine="text-davinci-003",
                    prompt=prompt,
                    max_tokens=max_allowed_tokens,
                    n=1,
                    stop=None,
                    temperature=0.2,
                )
            result_list.extend(json.loads(response.choices[0].text))
    return result_list

# %%
get_result(goal, links, crawl_prompt_template, 'https://docs.bunny.net/reference/bunnynet-api-overview')

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
      {"role": "system", "content": "AI assistant that builds software based on prompts that always returns valid JSON output."},
      {"role": "user", "content": """
      Given the following list of links return the URLs that will help the most 
        while researching to achieve the goal to "create an Python SDK for the bunny.net API".
        If the link is a relative URL ("/some/relative-link") convert it to an absolute URL 
        ("https://docs.bunny.net/some/relative-link") using this hostname: https://docs.bunny.net.
        Make sure to output valid JSON using the following JSON template for your output [{"link": "http://example.com"}]:
        <a class="Button Button_md Header-jumpTo3IWKQXmhSI5D rm-JumpTo Button_primary" href="#content" target="_self">Jump to Content</a>,<a class="Header-logo1Xy41PtkzbdG rm-Logo" href="/" target="_self"><img alt="bunny.net Developer Hub" class="Header-logo-img3YvV4lcGKkeb rm-Logo-img" src="https://files.readme.io/649bcfb-small-bunnynet-logo-dark.png"/></a>,<a class="Button Button_md Button_slate_text rm-Header-top-link Header-link2tXYTgXq85zW" href="https://status.bunnycdn.com/" target="_self" to="https://status.bunnycdn.com/">Service Status</a>,<a class="Button Button_md Button_slate_text rm-Header-top-link Header-link2tXYTgXq85zW" href="https://support.bunny.net/hc/en-us" target="_self" to="https://support.bunny.net/hc/en-us">Support Hub</a>,<a class="Button Button_md Button_slate_text rm-Header-top-link Header-link2tXYTgXq85zW" href="/cdn-cgi/l/email-protection#dfacaaafafb0adab9fbdaab1b1a6f1b1baab" target="_self" to="mailto:support@bunny.net"><span class="__cf_email__" data-cfemail="097a7c7979667b7d496b7c67677027676c7d">[email protected]</span></a>,<a class="NavItem-item1gDDTqaXGhm1 NavItem-item_mobile1qG3gd-Mkck-" href="/docs" target="_self"><i class="NavItem-item-anchorzz3banOxXKjr icon-guides"></i><span class="NavItem-textSlZuuL489uiw">Documentation</span></a>,<a aria-current="page" class="NavItem-item1gDDTqaXGhm1 NavItem-item_mobile1qG3gd-Mkck- active" href="/reference" target="_self"><i class="NavItem-item-anchorzz3banOxXKjr icon-references"></i><span class="NavItem-textSlZuuL489uiw">API Reference</span></a>,<a class="NavItem-item1gDDTqaXGhm1 NavItem-item_mobile1qG3gd-Mkck- NavItem_dropdown-muted1xJVuczwGc74" href="/cdn-cgi/l/email-protection#dba8aeababb4a9af9bb9aeb5b5a2f5b5beaf" target="_self" to="mailto:support@bunny.net"><span class="__cf_email__" data-cfemail="10636560607f62645072657e7e693e7e7564">[email protected]</span></a>,<a class="NavItem-item1gDDTqaXGhm1 NavItem-item_mobile1qG3gd-Mkck- NavItem_dropdown-muted1xJVuczwGc74" href="/login?redirect_uri=/reference/bunnynet-api-overview" target="_self" to="/login?redirect_uri=/reference/bunnynet-api-overview">Log In</a>,<a aria-current="page" class="Sidebar-link2Dsha-r-GKh2 childless text-wrap rm-Sidebar-link active" href="/reference/bunnynet-api-overview" target="_self"><span class="Sidebar-link-textLuTE1ySm4Kqn"><span>API Overview</span></span></a>,
      """}
  ],
    temperature=0.3
)

# %%
response

# %%
chat_id = response['id']
json_response = json.loads(response['choices'][0]['message']['content'])

# %%
json_response

# %%
chat_id

# %%
from codeagi.actions import ResearchAction

ra = ResearchAction()('Read FaunaDB documentation', 'Create a Fauna-based blogging engine')
# Out:
# Search Term:  FaunaDB documentation
# Result List:  ['https://docs.fauna.com/fauna/current/', 'https://docs.fauna.com/fauna/current/', 'https://fauna.com/home', 'https://pythonhosted.org/faunadb/', 'https://docs.rs/faunadb/', 'https://github.com/fauna/faunadb-python', 'https://apitracker.io/a/fauna', 'https://yarnpkg.com/package/faunadb', 'https://readthedocs.org/projects/faunadb-python/', 'https://fauna.com/features', 'https://yarnpkg.com/package/faunadb', 'https://readthedocs.org/projects/faunadb-python/']
# Prompt:
#         Which link out of the list below is the best to use for research for FaunaDB documentation?
#         Generate a JSON response with the following template: {"link": "result_list"}
#         ['https://docs.fauna.com/fauna/current/', 'https://docs.fauna.com/fauna/current/', 'https://fauna.com/home', 'https://pythonhosted.org/faunadb/', 'https://docs.rs/faunadb/', 'https://github.com/fauna/faunadb-python', 'https://apitracker.io/a/fauna', 'https://yarnpkg.com/package/faunadb', 'https://readthedocs.org/projects/faunadb-python/', 'https://fauna.com/features', 'https://yarnpkg.com/package/faunadb', 'https://readthedocs.org/projects/faunadb-python/']
#
# Best Link:  https://docs.fauna.com/fauna/current/
# #1 OpenAI Request
# Raw Response:
#         [{"link": "https://docs.fauna.com/fauna/current/start/intro.html"}, {"link": "https://www.fauna.com/blog/building-a-serverless-blogging-engine-on-fauna"}, {"link": "https://www.youtube.com/watch?v=Vl4EJhV_2C4"}, {"link": "https://www.fauna.com/blog/building-a-serverless-blogging-engine-on-fauna"}]
# #2 OpenAI Request
# #3 OpenAI Request
# #4 OpenAI Request
# #5 OpenAI Request
# #6 OpenAI Request
# #7 OpenAI Request
# #8 OpenAI Request
# #9 OpenAI Request
# #10 OpenAI Request
# #11 OpenAI Request
# #12 OpenAI Request
# #13 OpenAI Request
# #14 OpenAI Request
# #15 OpenAI Request
# #16 OpenAI Request
# #17 OpenAI Request
# #18 OpenAI Request
# #19 OpenAI Request
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Community Support Log in Start for Free Fauna current v4 v3 Page Not Found The page you’re looking for does not exist. It may have been moved. You can return to the start page, or follow one of the links in the navigation to the left. If you arrived on this page by clicking on a link, please notify the owner of the site that the link is broken. If you typed the URL of this page manually, please double check that you entered the address correctly. Copyright © 2018–2023 Fauna, Inc. Terms of use Privacy Policy ? ↑ × Keyboard shortcuts While reading ? or h Shows this help. / or Alt+f or ⌘Control+K Focus the search field. ← Navigate to the previous page (higher up the TOC). → Navigate to the next page (lower down the TOC). [ Switch to the previous language (to the left, wraps around). ] Switch to
#
# Summary:  {'summary': 'This page informs the user that the page they are looking for does not exist, and provides tips on how to find the page they are looking for.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         the next language (to the right, wraps around). t Scroll to the top of the page. b Scroll to the bottom of the page. While searching Enter Navigate to the highlighted search result. Esc Deselect the search field and hide the search results. ↑ Highlight the previous search result. ↓ Highlight the next search result. URL fragments Use the following URL fragments to scroll to parts of a page: #/term Scroll to the first instance of term on the page. #Pn Scroll to the nth paragraph on the page. #Sn Scroll the nth percentage of the page height.
#
# Summary:  {'summary': 'This page provides instructions for navigating a page, including scrolling to the top or bottom of a page, searching for a term, and using URL fragments to scroll to a specific part of the page.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         © 2023 Fauna, Inc. All Rights Reserved.400 S El Camino Real Ste 1250San Mateo, CA 94402(855) 432-8623
#
# Summary:  {'summary': 'This page provides information about creating a Fauna-based blogging engine. It includes code snippets to help users create a valid JSON output.', 'relevant_code_snippets': ['JSON template to output valid JSON only: { "summary": "", "relevant_code_snippets": [] }']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         AboutPressCopyrightContact usCreatorsAdvertiseDevelopersTermsPrivacyPolicy & SafetyHow YouTube worksTest new featuresNFL Sunday Ticket© 2023 Google LLC
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         📙 The architect's guide to building scalable global applications |Learn moreProductSolutionsPricingResourcesCustomersCompanyLog InContact usStart for freeProduct Solutions PricingResources CustomersCompany Log InContact usStart for free© 2023 Fauna, Inc. All Rights Reserved.The page you were looking for was not found.If you are looking for a page check the url again or return home by clicking the button below.Back home400 S El Camino Real Ste 1250San Mateo, CA 94402(855) 432-8623FAUNA STATUSFaunaFeaturesPlatformSolutionsPricingCustomersTrustBlogFauna CompanyAboutEventsPressCareersContact UsCompany QuicklinksForumsHelpdeskPartner with FaunaQuicklinks Why FaunaDynamoDB alternativeFauna vs MongoDBFauna vs DynamoDBFauna vs Aurora Serverless V2Fauna vs PostgresWhy Fauna © Fauna Inc. All rights reserved.StatusSitemapTerms
#
# Summary:  {'summary': "This page provides information about Fauna, Inc., a company that specializes in building scalable global applications. It provides details about the company, its products, solutions, pricing, customers, and more. It also provides links to the company's blog, forums, helpdesk, and more.", 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         of UsePrivacy Policy
#
# Summary:  {'summary': 'This page provides instructions on how to create a Fauna-based blogging engine, including relevant code snippets to output valid JSON.', 'relevant_code_snippets': ["jsonTemplate = { 'key': 'value' }", "blogEngine = { 'title': 'Fauna-based Blogging Engine' }"]}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Community Support Log in Start for Free Welcome Learn Introduction What is Fauna? What is a document-relational database? Key Concepts Data model, querying, and security Plan your data management strategy FQL for SQL users Quick start Dashboard GraphQL Client application Understanding Fauna Databases Collections Documents Indexes User-defined functions Event streaming Temporality Data types Region Groups Backups Isolation levels Billing Limits Sample apps Fwitter Tutorials FQL CRUD FQL basics Indexes Data modeling Functions Authentication and authorization Indexes Pagination Sort Search Search and sort Bindings Authentication User authentication Attribute-based access control (ABAC) Temporality Multi-tenancy Social graph E-commerce Write throughput scaling Combination field filtering GraphQL
#
# Summary:  {'summary': 'This page provides an introduction to Fauna, a document-relational database, and provides tutorials for using FQL, CRUD, Indexes, Data Modeling, Functions, Authentication and Authorization, Pagination, Sort, Search, and more to create a Fauna-based blogging engine.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Relations One-to-many self-referential relations Many-to-many self-referential relations Unique constraints Pagination User-defined functions Cookbook FQL Basics Collections Create Create a document Create many documents Delete Get List Metadata Rename Databases Create Delete Get List Metadata Rename Documents Reference Create Create many Upsert Functions Call Create Delete Get List Metadata Rename Indexes Create Delete Get List Query Metadata Rename Keys Create Delete Get List Metadata Tokens Create Delete Get List Metadata Array Zip together two arrays Math Unsigned integer subtraction Search List of terms Missing field value Null field Duplicate values List of terms using a UDF Search a date range Strings Split a string by a delimiter GraphQL GraphQL counter Sorting GraphQL results Search
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including one-to-many and many-to-many self-referential relations, unique constraints, pagination, user-defined functions, FQL Basics, collections, databases, documents, functions, indexes, keys, tokens, array zip together, math unsigned integer subtraction, search list of terms, missing field value, null field, duplicate values, search a date range, strings split a string by a delimiter, GraphQL counter, sorting GraphQL results, and search.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         a date range Composable Types without Unions Model Unions as a single type Model Unions as sparse fields A "Component" pattern for GraphQL Build Developing with FQL Fauna drivers C# Go Java JavaScript Python Scala Basic CRUD operations Query composition Working with data types Indexes Index terms Values Bindings Pagination Multi-collection indexes Temporality and indexes Combining and comparing result sets User-defined functions Using temporality Error handling Best practices Database performance Defensive query strategies HTTP timeouts Indexes Security Tools Fauna Dashboard Multi-factor authentication Team management Fauna Dev fauna-shell Configuration Commands add-endpoint autocomplete cloud-login create-database create-key default-endpoint delete-database delete-endpoint delete-key eval
#
# Summary:  {'summary': 'This page provides an overview of developing with Fauna, including information on Composable Types, Unions, GraphQL, CRUD operations, Indexes, Data Types, Query Composition, User-defined Functions, Error Handling, Best Practices, Database Performance, Defensive Query Strategies, HTTP Timeouts, Indexes, Security Tools, Fauna Dashboard, Multi-factor Authentication, Team Management, Fauna Dev, and Fauna Shell Configuration Commands.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         help import list-databases list-endpoints list-keys shell upload-graphql-schema Logins for GitHub or Netlify users VS Code extension Logs Query log Dashboard operations API automation Reference /api/v1/logs /api/v1/logs/{requestId} /api/v1/logs/{request_id}/url /api/v1/logs/_list Log record format Integrations Airbyte Appsmith Cloudflare Workers Fastly Compute@Edge Netlify Add-on Retool Vercel integration WunderGraph API references GraphQL Endpoints Error responses Directives @collection @embedded @generateUDFResolvers @index @relation @resolver @unique Schemas Input types Relationships User-defined functions FQL FQL cheat sheet Indexes Deprecations Known issues Built-in functions Abort Abs AccessProvider AccessProviders Acos Add All And Any Append Asin At Atan BitAnd BitNot BitOr BitXor Call
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including how to use the JSON template to output valid JSON, how to use the Logins for GitHub or Netlify users, how to access the GraphQL Endpoints, how to use Directives, Schemas, Input types, Relationships, User-defined functions, FQL, Indexes, Built-in functions, and more.', 'relevant_code_snippets': ['help import list-databases list-endpoints list-keys shell upload-graphql-schema Logins for GitHub or Netlify users VS Code extension Logs Query log Dashboard operations API automation Reference /api/v1/logs /api/v1/logs/{requestId} /api/v1/logs/{request_id}/url /api/v1/logs/_list Log record format Integrations Airbyte Appsmith Cloudflare Workers Fastly Compute@Edge Netlify Add-on Retool Vercel integration WunderGraph API references GraphQL Endpoints Error responses Directives @collection @embedded @generateUDFResolvers @index @relation @resolver @unique Schemas Input types Relationships User-defined functions FQL FQL cheat sheet Indexes Deprecations Known issues Built-in functions Abort Abs AccessProvider AccessProviders Acos Add All And Any Append Asin At Atan BitAnd BitNot BitOr BitXor Call']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Casefold Ceil Class Classes Collection Collections Concat Contains ContainsField ContainsPath ContainsStr ContainsStrRegex ContainsValue Cos Cosh Count Create CreateAccessProvider CreateClass CreateCollection CreateDatabase CreateFunction CreateIndex CreateKey CreateRole Credentials CurrentIdentity CurrentToken Database Databases Date DayOfMonth DayOfWeek DayOfYear Degrees Delete Difference Distinct Divide Do Documents Drop EndsWith Epoch Equals Events Exists Exp Filter FindStr FindStrRegex Floor Foreach Format Function Functions GT GTE Get HasCurrentIdentity HasIdentity HasCurrentToken Hour Hypot Identify Identity If Index Indexes Insert Intersection IsArray IsBoolean IsBytes IsCollection IsCredentials IsDatabase IsDate IsDoc IsDouble IsEmpty IsFunction IsIndex IsInteger IsKey IsLambda IsNonEmpty
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including details on how to use JSON templates to output valid JSON.', 'relevant_code_snippets': ['CreateAccessProvider', 'CreateClass', 'CreateCollection', 'CreateDatabase', 'CreateFunction', 'CreateIndex', 'CreateKey', 'CreateRole', 'Credentials', 'CurrentIdentity', 'CurrentToken', 'Database', 'Databases', 'Delete', 'Insert', 'IsArray', 'IsBoolean', 'IsBytes', 'IsCollection', 'IsCredentials', 'IsDatabase', 'IsDate', 'IsDoc', 'IsDouble', 'IsEmpty', 'IsFunction', 'IsIndex', 'IsInteger', 'IsKey', 'IsLambda', 'IsNonEmpty']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         IsNull IsNumber IsObject IsRef IsRole IsSet IsString IsTimestamp IsToken Join KeyFromSecret Keys LT LTE LTrim Lambda Length Let Ln Log Login Logout LowerCase Map Match Max Mean Merge Min Minute Modulo Month MoveDatabase Multiply NewId Not Now Or Paginate Pow Prepend Query RTrim Radians Range Reduce Ref RegexEscape Remove Repeat Replace ReplaceStr ReplaceStrRegex Reverse Role Roles Round Second Select SelectAll Sign Sin Singleton Sinh Space Sqrt StartsWith SubString Subtract Sum Take Tan Tanh Time TimeAdd TimeDiff TimeSubtract TitleCase ToArray ToDate ToDouble ToInteger ToMicros ToMillis ToNumber ToObject ToSeconds ToString ToTime Tokens Trim Trunc Union Update UpperCase Var Year Drivers Version strategy Imports Connections C# Go JVM (Java, Scala) JavaScript Python Known issues Security Keys
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including drivers, versions, strategy, imports, connections, and language support (C#, Go, JVM, JavaScript, Python). It also provides information on known issues and security keys.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Tokens External authentication JSON Web Tokens (JWTs) AccessProvider Auth0 configuration Clerk setup Credentials Attribute-based access control (ABAC) ABAC best practices Role-based authentication Identity-based authentication User-defined roles Permissions Delegates References Glossary Fauna current Fauna current v4 v3 Welcome Welcome to the Fauna documentation What is Fauna? Learn More Fauna is a flexible, developer-friendly, transactional database delivered as a secure and scalable cloud API with native GraphQL. Fauna combines the flexibility of NoSQL systems with the relational querying and transactional capabilities of SQL databases. Try it out Quick start Get up and running quickly with an interactive introduction to Fauna. Quick start Build a sample app Sample apps show Fauna features
#
# Summary:  {'summary': 'Fauna is a flexible, developer-friendly, transactional database delivered as a secure and scalable cloud API with native GraphQL. This page provides an introduction to Fauna, quick start instructions, and sample apps to show Fauna features.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         and capabilities in an application context. Sample apps New to Fauna Query Language? The SQL to FQL translation reference can help you get started. FQL for SQL Users Workshops Build GraphQL and AWS applications. Workshops Driver support To start querying Fauna from your application code, choose your language: GraphQL JS/Node Java C# Go Python Scala What is in the documentation? These three main content sections can help you learn Fauna: Cookbook Query and code examples for databases, collections, indexes, and user-defined functions. Cookbook Tools Full descriptions of the tools available with Fauna. Tools API Reference Complete reference materials for the APIs you can use to interact with Fauna. API reference Explore key features A selection of features that make Fauna easy to get started,
#
# Summary:  {'summary': 'This page provides resources to help users learn Fauna Query Language and how to use it to build GraphQL and AWS applications. It includes a cookbook, tools, and API reference, as well as driver support for various languages. ', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         powerful, and unique: Security Configure authentication and access controls. View docs Data Import Import JSON or CSV data into your database. View docs Streaming Stream changes to a client application. View docs Backups Learn about built-in daily backup management and recovery. View docs Query Log Download near real-time query logs for enhanced database observability. View docs Is this article helpful? No Yes Tell Fauna how the article can be improved: Visit Fauna's forums or email docs@fauna.com Thank you for your feedback! Learn Copyright © 2018–2023 Fauna, Inc. Terms of use Privacy Policy ? ↑ × Keyboard shortcuts While reading ? or h Shows this help. / or Alt+f or ⌘Control+K Focus the search field. ← Navigate to the previous page (higher up the TOC). → Navigate to the next page (lower down
#
# Summary:  {'summary': 'Fauna is a powerful and unique database system that allows users to configure authentication and access controls, import JSON or CSV data, stream changes to a client application, manage and recover backups, and download near real-time query logs for enhanced database observability.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         the TOC). [ Switch to the previous language (to the left, wraps around). ] Switch to the next language (to the right, wraps around). t Scroll to the top of the page. b Scroll to the bottom of the page. While searching Enter Navigate to the highlighted search result. Esc Deselect the search field and hide the search results. ↑ Highlight the previous search result. ↓ Highlight the next search result. URL fragments Use the following URL fragments to scroll to parts of a page: #/term Scroll to the first instance of term on the page. #Pn Scroll to the nth paragraph on the page. #Sn Scroll the nth percentage of the page height.
#
# Summary:  {'summary': 'This page provides instructions on how to navigate a page, search for terms, and scroll to parts of a page using URL fragments.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         © 2023 Fauna, Inc. All Rights Reserved.400 S El Camino Real Ste 1250San Mateo, CA 94402(855) 432-8623
#
# Summary:  {'summary': 'This page provides instructions on how to create a Fauna-based blogging engine using the Fauna Query Language (FQL) and the Fauna JavaScript SDK.', 'relevant_code_snippets': ["const query = await query(q.Create(q.Collection('posts'), { data: { title: 'My First Post' } }))", "const query = await query(q.Create(q.Collection('comments'), { data: { post_id: post.ref.id, content: 'This is a comment' } }))"]}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         © 2023 Fauna, Inc. All Rights Reserved.400 S El Camino Real Ste 1250San Mateo, CA 94402(855) 432-8623
#
# Summary:  {'summary': 'This page provides instructions on how to create a Fauna-based blogging engine using the Fauna Query Language (FQL) and Fauna JavaScript SDK.', 'relevant_code_snippets': ["const query = await fauna.query(q.Create(q.Collection('posts'), { data: { title: 'My First Post' }}));", "const query = await fauna.query(q.Create(q.Ref('posts'), { data: { title: 'My Second Post' }}));", "const query = await fauna.query(q.Create(q.Ref('comments'), { data: { post_ref: post.ref, content: 'This is a comment' }}));"]}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Join the Fauna Community! Get your questions answered and share your knowledge. Fauna Forums For help from the Fauna team, or to make roadmap feature requests, use the forums. We monitor the forums very closely and respond promptly. Feature Requests Help Fauna Community Discord Mingle with your peers, showcase your projects, and chat in real-time. Follow this link to join or sign in.
#
# Summary:  {'summary': 'Join the Fauna Community! Get your questions answered and share your knowledge by using the forums and joining the Fauna Community Discord.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Please stand by, while we are checking your browser... Redirecting... Please turn JavaScript on and reload the page. Please enable Cookies and reload the page. RayID: 7bf90f2d689d2442 IP: 75.40.153.163
#
# Summary:  {'summary': 'This page requires JavaScript, Cookies, and RayID to be enabled in order to create a Fauna-based blogging engine.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         You need to enable JavaScript to run this app.
#
# Summary:  {'summary': 'This page provides instructions on how to create a Fauna-based blogging engine. It requires JavaScript to be enabled in order to run.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Community Support Log in Start for Free Welcome Learn Introduction What is Fauna? What is a document-relational database? Key Concepts Data model, querying, and security Plan your data management strategy FQL for SQL users Quick start Dashboard GraphQL Client application Understanding Fauna Databases Collections Documents Indexes User-defined functions Event streaming Temporality Data types Region Groups Backups Isolation levels Billing Limits Sample apps Fwitter Tutorials FQL CRUD FQL basics Indexes Data modeling Functions Authentication and authorization Indexes Pagination Sort Search Search and sort Bindings Authentication User authentication Attribute-based access control (ABAC) Temporality Multi-tenancy Social graph E-commerce Write throughput scaling Combination field filtering GraphQL
#
# Summary:  {'summary': 'Fauna is a document-relational database that offers data modeling, querying, and security features. It provides tutorials, sample apps, and client applications to help users create a Fauna-based blogging engine. It also offers features such as FQL CRUD, indexes, data modeling, functions, authentication and authorization, temporality, multi-tenancy, social graph, e-commerce, write throughput scaling, combination field filtering, and GraphQL.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Relations One-to-many self-referential relations Many-to-many self-referential relations Unique constraints Pagination User-defined functions Cookbook FQL Basics Collections Create Create a document Create many documents Delete Get List Metadata Rename Databases Create Delete Get List Metadata Rename Documents Reference Create Create many Upsert Functions Call Create Delete Get List Metadata Rename Indexes Create Delete Get List Query Metadata Rename Keys Create Delete Get List Metadata Tokens Create Delete Get List Metadata Array Zip together two arrays Math Unsigned integer subtraction Search List of terms Missing field value Null field Duplicate values List of terms using a UDF Search a date range Strings Split a string by a delimiter GraphQL GraphQL counter Sorting GraphQL results Search
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including information on relations, pagination, user-defined functions, FQL basics, collections, databases, documents, functions, indexes, keys, tokens, arrays, math, search, strings, and GraphQL.', 'relevant_code_snippets': ['Create a document', 'Create many documents', 'Delete', 'Get', 'List', 'Metadata', 'Rename', 'Create a database', 'Delete a database', 'Get a database', 'List databases', 'Metadata for a database', 'Rename a database', 'Reference a document', 'Create a document', 'Create many documents', 'Upsert a document', 'Call a function', 'Create a function', 'Delete a function', 'Get a function', 'List functions', 'Metadata for a function', 'Rename a function', 'Create an index', 'Delete an index', 'Get an index', 'List indexes', 'Query an index', 'Metadata for an index', 'Rename an index', 'Create a key', 'Delete a key', 'Get a key', 'List keys', 'Metadata for a key', 'Create a token', 'Delete a token', 'Get a token', 'List tokens', 'Metadata for a token', 'Array zip together two arrays', 'Math unsigned integer subtraction', 'Search list of terms', 'Missing field value', 'Null field', 'Duplicate values', 'List of terms using a UDF', 'Search a date range', 'Strings split a string by a delimiter', 'GraphQL counter', 'Sorting GraphQL results', 'Search']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         a date range Composable Types without Unions Model Unions as a single type Model Unions as sparse fields A "Component" pattern for GraphQL Build Developing with FQL Fauna drivers C# Go Java JavaScript Python Scala Basic CRUD operations Query composition Working with data types Indexes Index terms Values Bindings Pagination Multi-collection indexes Temporality and indexes Combining and comparing result sets User-defined functions Using temporality Error handling Best practices Database performance Defensive query strategies HTTP timeouts Indexes Security Tools Fauna Dashboard Multi-factor authentication Team management Fauna Dev fauna-shell Configuration Commands add-endpoint autocomplete cloud-login create-database create-key default-endpoint delete-database delete-endpoint delete-key eval
#
# Summary:  {'summary': 'This page provides information on developing a Fauna-based blogging engine, including topics such as Composable Types, Unions, GraphQL, CRUD operations, Indexes, Data Types, Error Handling, Security, and Tools.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         help import list-databases list-endpoints list-keys shell upload-graphql-schema Logins for GitHub or Netlify users VS Code extension Logs Query log Dashboard operations API automation Reference /api/v1/logs /api/v1/logs/{requestId} /api/v1/logs/{request_id}/url /api/v1/logs/_list Log record format Integrations Airbyte Appsmith Cloudflare Workers Fastly Compute@Edge Netlify Add-on Retool Vercel integration WunderGraph API references GraphQL Endpoints Error responses Directives @collection @embedded @generateUDFResolvers @index @relation @resolver @unique Schemas Input types Relationships User-defined functions FQL FQL cheat sheet Indexes Deprecations Known issues Built-in functions Abort Abs AccessProvider AccessProviders Acos Add All And Any Append Asin At Atan BitAnd BitNot BitOr BitXor Call
#
# Summary:  {'summary': "This page provides information about Fauna's logging capabilities, integrations, API references, GraphQL endpoints, error responses, schemas, input types, relationships, user-defined functions, FQL cheat sheet, indexes, deprecations, known issues, and built-in functions.", 'relevant_code_snippets': ['help import list-databases list-endpoints list-keys shell upload-graphql-schema Logins for GitHub or Netlify users VS Code extension Logs Query log Dashboard operations API automation Reference /api/v1/logs /api/v1/logs/{requestId} /api/v1/logs/{request_id}/url /api/v1/logs/_list Log record format Integrations Airbyte Appsmith Cloudflare Workers Fastly Compute@Edge Netlify Add-on Retool Vercel integration WunderGraph API references GraphQL Endpoints Error responses Directives @collection @embedded @generateUDFResolvers @index @relation @resolver @unique Schemas Input types Relationships User-defined functions FQL FQL cheat sheet Indexes Deprecations Known issues Built-in functions Abort Abs AccessProvider AccessProviders Acos Add All And Any Append Asin At Atan BitAnd BitNot BitOr BitXor Call']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Casefold Ceil Class Classes Collection Collections Concat Contains ContainsField ContainsPath ContainsStr ContainsStrRegex ContainsValue Cos Cosh Count Create CreateAccessProvider CreateClass CreateCollection CreateDatabase CreateFunction CreateIndex CreateKey CreateRole Credentials CurrentIdentity CurrentToken Database Databases Date DayOfMonth DayOfWeek DayOfYear Degrees Delete Difference Distinct Divide Do Documents Drop EndsWith Epoch Equals Events Exists Exp Filter FindStr FindStrRegex Floor Foreach Format Function Functions GT GTE Get HasCurrentIdentity HasIdentity HasCurrentToken Hour Hypot Identify Identity If Index Indexes Insert Intersection IsArray IsBoolean IsBytes IsCollection IsCredentials IsDatabase IsDate IsDoc IsDouble IsEmpty IsFunction IsIndex IsInteger IsKey IsLambda IsNonEmpty
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including relevant code snippets for creating collections, databases, functions, indexes, keys, and roles.', 'relevant_code_snippets': ['CreateCollection', 'CreateDatabase', 'CreateFunction', 'CreateIndex', 'CreateKey', 'CreateRole']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         IsNull IsNumber IsObject IsRef IsRole IsSet IsString IsTimestamp IsToken Join KeyFromSecret Keys LT LTE LTrim Lambda Length Let Ln Log Login Logout LowerCase Map Match Max Mean Merge Min Minute Modulo Month MoveDatabase Multiply NewId Not Now Or Paginate Pow Prepend Query RTrim Radians Range Reduce Ref RegexEscape Remove Repeat Replace ReplaceStr ReplaceStrRegex Reverse Role Roles Round Second Select SelectAll Sign Sin Singleton Sinh Space Sqrt StartsWith SubString Subtract Sum Take Tan Tanh Time TimeAdd TimeDiff TimeSubtract TitleCase ToArray ToDate ToDouble ToInteger ToMicros ToMillis ToNumber ToObject ToSeconds ToString ToTime Tokens Trim Trunc Union Update UpperCase Var Year Drivers Version strategy Imports Connections C# Go JVM (Java, Scala) JavaScript Python Known issues Security Keys
#
# Summary:  {'summary': 'This page provides information about Fauna, a database service for applications, and how to create a Fauna-based blogging engine. It includes information about drivers, versions, strategies, imports, connections, known issues, security, and keys.', 'relevant_code_snippets': ['IsNull', 'IsNumber', 'IsObject', 'IsRef', 'IsRole', 'IsSet', 'IsString', 'IsTimestamp', 'IsToken', 'Join', 'KeyFromSecret', 'Keys', 'LT', 'LTE', 'LTrim', 'Lambda', 'Length', 'Let', 'Ln', 'Log', 'Login', 'Logout', 'LowerCase', 'Map', 'Match', 'Max', 'Mean', 'Merge', 'Min', 'Minute', 'Modulo', 'Month', 'MoveDatabase', 'Multiply', 'NewId', 'Not', 'Now', 'Or', 'Paginate', 'Pow', 'Prepend', 'Query', 'RTrim', 'Radians', 'Range', 'Reduce', 'Ref', 'RegexEscape', 'Remove', 'Repeat', 'Replace', 'ReplaceStr', 'ReplaceStrRegex', 'Reverse', 'Role', 'Roles', 'Round', 'Second', 'Select', 'SelectAll', 'Sign', 'Sin', 'Singleton', 'Sinh', 'Space', 'Sqrt', 'StartsWith', 'SubString', 'Subtract', 'Sum', 'Take', 'Tan', 'Tanh', 'Time', 'TimeAdd', 'TimeDiff', 'TimeSubtract', 'TitleCase', 'ToArray', 'ToDate', 'ToDouble', 'ToInteger', 'ToMicros', 'ToMillis', 'ToNumber', 'ToObject', 'ToSeconds', 'ToString', 'ToTime', 'Tokens', 'Trim', 'Trunc', 'Union', 'Update', 'UpperCase', 'Var', 'Year', 'Drivers', 'Version', 'Strategy', 'Imports', 'Connections', 'C#', 'Go', 'JVM (Java, Scala)', 'JavaScript', 'Python', 'Known issues', 'Security', 'Keys']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Tokens External authentication JSON Web Tokens (JWTs) AccessProvider Auth0 configuration Clerk setup Credentials Attribute-based access control (ABAC) ABAC best practices Role-based authentication Identity-based authentication User-defined roles Permissions Delegates References Glossary Fauna current Fauna current v4 v3 Welcome Welcome to the Fauna documentation What is Fauna? Learn More Fauna is a flexible, developer-friendly, transactional database delivered as a secure and scalable cloud API with native GraphQL. Fauna combines the flexibility of NoSQL systems with the relational querying and transactional capabilities of SQL databases. Try it out Quick start Get up and running quickly with an interactive introduction to Fauna. Quick start Build a sample app Sample apps show Fauna features
#
# Summary:  {'summary': 'Fauna is a flexible, developer-friendly, transactional database delivered as a secure and scalable cloud API with native GraphQL. Fauna combines the flexibility of NoSQL systems with the relational querying and transactional capabilities of SQL databases. This documentation provides an interactive introduction to Fauna, as well as sample apps to show Fauna features such as External authentication, JSON Web Tokens (JWTs), AccessProvider, Auth0 configuration, Clerk setup, Credentials, Attribute-based access control (ABAC), ABAC best practices, Role-based authentication, Identity-based authentication, User-defined roles, Permissions, Delegates, References, and Glossary.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         and capabilities in an application context. Sample apps New to Fauna Query Language? The SQL to FQL translation reference can help you get started. FQL for SQL Users Workshops Build GraphQL and AWS applications. Workshops Driver support To start querying Fauna from your application code, choose your language: GraphQL JS/Node Java C# Go Python Scala What is in the documentation? These three main content sections can help you learn Fauna: Cookbook Query and code examples for databases, collections, indexes, and user-defined functions. Cookbook Tools Full descriptions of the tools available with Fauna. Tools API Reference Complete reference materials for the APIs you can use to interact with Fauna. API reference Explore key features A selection of features that make Fauna easy to get started,
#
# Summary:  {'summary': 'Fauna provides a Query Language, workshops, driver support, documentation, and key features to help developers create a Fauna-based blogging engine.', 'relevant_code_snippets': []}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
# ...
#
# Summary:  {'summary': 'This page provides information on how to create a Fauna-based blogging engine, including information on logins, logs, dashboard operations, API automation, GraphQL endpoints, schemas, input types, relationships, user-defined functions, FQL cheat sheet, indexes, deprecations, known issues, and built-in functions.', 'relevant_code_snippets': ['help import list-databases list-endpoints list-keys shell upload-graphql-schema Logins for GitHub or Netlify users VS Code extension Logs Query log Dashboard operations API automation Reference /api/v1/logs /api/v1/logs/{requestId} /api/v1/logs/{request_id}/url /api/v1/logs/_list Log record format Integrations Airbyte Appsmith Cloudflare Workers Fastly Compute@Edge Netlify Add-on Retool Vercel integration WunderGraph API references GraphQL Endpoints Error responses Directives @collection @embedded @generateUDFResolvers @index @relation @resolver @unique Schemas Input types Relationships User-defined functions FQL FQL cheat sheet Indexes Deprecations Known issues Built-in functions Abort Abs AccessProvider AccessProviders Acos Add All And Any Append Asin At Atan BitAnd BitNot BitOr BitXor Call']}
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Summary Prompt:
#         Given the body of the page, return the summary (with minimal text) and relevant code snippets from the page below for the goal of "Create a Fauna-based blogging engine" using the following JSON template to output valid JSON only:
#         { "summary": "", "relevant_code_snippets": [] }
#         Casefold Ceil Class Classes Collection Collections Concat Contains ContainsField ContainsPath ContainsStr ContainsStrRegex ContainsValue Cos Cosh Count Create CreateAccessProvider CreateClass CreateCollection CreateDatabase CreateFunction CreateIndex CreateKey CreateRole Credentials CurrentIdentity CurrentToken Database Databases Date DayOfMonth DayOfWeek DayOfYear Degrees Delete Difference Distinct Divide Do Documents Drop EndsWith Epoch Equals Events Exists Exp Filter FindStr FindStrRegex Floor Foreach Format Function Functions GT GTE Get HasCurrentIdentity HasIdentity HasCurrentToken Hour Hypot Identify Identity If Index Indexes Insert Intersection IsArray IsBoolean IsBytes IsCollection IsCredentials IsDatabase IsDate IsDoc IsDouble IsEmpty IsFunction IsIndex IsInteger IsKey IsLambda IsNonEmpty
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /usr/local/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1348 try:
# -> 1349     response.begin()
#    1350 except ConnectionError:
#
# File /usr/local/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File /usr/local/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File /usr/local/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File /usr/local/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File /usr/local/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/openai/api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/requests/adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     577 elif isinstance(e, ReadTimeoutError):
# --> 578     raise ReadTimeout(e, request=request)
#     579 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
#
# The above exception was the direct cause of the following exception:
#
# Timeout                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 from codeagi.actions import ResearchAction
# ----> 3 ra = ResearchAction()('Read FaunaDB documentation', 'Create a Fauna-based blogging engine')
#
# File /code/codeagi/actions.py:58, in ResearchAction.__call__(self, task, goal)
#      51 """
#      52 Search Google for research
#      53 Args:
#      54     search_term: The search term to use
#      55 """
#      57 # Ask OpenAI what is the best link to use from the result list
# ---> 58 return self.search(task, goal)
#
# File /code/codeagi/actions.py:141, in ResearchAction.search(self, task, goal)
#     139 print('----------------------------------------------------------------------------------')
#     140 print('Summary Prompt: ', summary_prompt)
# --> 141 summary = self.call_gpt(summary_prompt)
#     142 print('Summary: ', summary)
#     143 print('----------------------------------------------------------------------------------')
#
# File /code/codeagi/actions.py:82, in ResearchAction.call_gpt(self, prompt)
#      80 max_allowed_tokens = 3500 - prompt_token_count
#      81 try:
# ---> 82     response = openai.Completion.create(
#      83         engine="text-davinci-003",
#      84         prompt=prompt,
#      85         max_tokens=max_allowed_tokens,
#      86         n=1,
#      87         stop=None,
#      88         temperature=0.5,
#      89     )
#      91     return json.loads(response.choices[0].text)
#      92 except (ConnectionResetError, requests.ConnectionError, json.JSONDecodeError):
#      93     # Try again
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/openai/api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~/.cache/pypoetry/virtualenvs/codeagi-MATOk_fk-py3.9/lib/python3.9/site-packages/openai/api_requestor.py:527, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#    (...)
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
# --> 527     raise error.Timeout("Request timed out: {}".format(e)) from e
#     528 except requests.exceptions.RequestException as e:
#     529     raise error.APIConnectionError(
#     530         "Error communicating with OpenAI: {}".format(e)
#     531     ) from e
#
# Timeout: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)

# %%
ra
# Out:
# ['https://www.fauna.com/blog/building-a-blog-with-fauna-graphql-and-react',
#  'https://www.fauna.com/blog/how-to-build-a-serverless-blog-with-fauna-db-and-react-hooks',
#  'https://www.fauna.com/blog/building-a-blog-with-fauna-and-gatsby',
#  'https://www.fauna.com/blog/building-a-serverless-blog-with-fauna-db-and-next-js',
#  'https://www.fauna.com/blog/building-a-serverless-blog-with-fauna-db-and-gridsome',
#  'https://docs.fauna.com',
#  'https://docs.fauna.com/fauna/current/tutorials/blogging-engine/',
#  'https://docs.fauna.com/fauna/current/api/fql/',
#  'https://community.fauna.com/',
#  'https://support.fauna.com/',
#  'https://dashboard.fauna.com/accounts/register',
#  'https://docs.fauna.com/fauna/current/learn/introduction/what_is_fauna',
#  'https://docs.fauna.com/fauna/current/learn/introduction/document_relational',
#  'https://docs.fauna.com/fauna/current/learn/introduction/key_concepts',
#  'https://docs.fauna.com/fauna/current/learn/introduction/data-model',
#  'https://docs.fauna.com/fauna/current/learn/introduction/implementation_path',
#  'https://docs.fauna.com/fauna/current/learn/introduction/fql_for_sql_users',
#  'https://docs.fauna.com/fauna/current/learn/quick_start/quick_start',
#  'https://docs.fauna.com/fauna/current/learn/quick_start/gql_quick_start',
#  'https://docs.fauna.com/fauna/current/learn/quick_start/client_quick_start',
#  'https://docs.fauna.com/fauna/current/learn/understanding/databases',
#  'https://docs.fauna.com/fauna/current/learn/understanding/collections',
#  'https://docs.fauna.com/fauna/current/learn/understanding/documents',
#  'https://docs.fauna.com/fauna/current/learn/understanding/indexes',
#  'https://docs.fauna.com/fauna/current/learn/understanding/user_defined_functions',
#  'https://docs.fauna.com/fauna/current/learn/understanding/streaming',
#  'https://docs.fauna.com/fauna/current/learn/understanding/temporality',
#  'https://docs.fauna.com/fauna/current/learn/understanding/types',
#  'https://docs.fauna.com/fauna/current/learn/understanding/region_groups',
#  'https://docs.fauna.com/fauna/current/learn/understanding/backups',
#  'https://docs.fauna.com/fauna/current/learn/understanding/isolation_levels',
#  'https://docs.fauna.com/fauna/current/learn/understanding/billing',
#  'https://docs.fauna.com/fauna/current/learn/understanding/limits',
#  'https://docs.fauna.com/fauna/current/learn/sample_apps/',
#  'https://docs.fauna.com/fauna/current/learn/sample_apps/fwitter',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/crud',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/basics/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/basics/indexes',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/basics/data_modeling',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/basics/functions',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/basics/authentication',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/indexes/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/indexes/pagination',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/indexes/sort',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/indexes/search',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/indexes/search_and_sort',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/indexes/bindings',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/authentication/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/authentication/user',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/authentication/abac',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/temporality',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/multitenant',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/social_graph',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/ecommerce',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/write_throughput_scaling',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/fql/combination_field_filtering',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/graphql/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/graphql/relations/',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/graphql/relations/self-one_to_many',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/graphql/relations/self-many_to_many',
#  'https://docs.fauna.com/fauna/current/learn/tutorials/graphql/unique',
#  'http://fauna/current/learn/tutorials/graphql/pagination',
#  'http://fauna/current/learn/tutorials/graphql/user_defined_functions',
#  'http://fauna/current/learn/cookbook/',
#  'http://fauna/current/learn/cookbook/fql/',
#  'http://fauna/current/learn/cookbook/fql/basics/',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/create',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/create_document',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/create_many_documents',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/delete',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/get',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/list',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/metadata',
#  'http://fauna/current/learn/cookbook/fql/basics/collections/rename',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/create',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/delete',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/get',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/list',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/metadata',
#  'http://fauna/current/learn/cookbook/fql/basics/databases/rename',
#  'http://fauna/current/learn/cookbook/fql/basics/documents/',
#  'http://fauna/current/learn/cookbook/fql/basics/documents/reference',
#  'http://fauna/current/learn/cookbook/fql/basics/documents/create',
#  'http://fauna/current/learn/cookbook/fql/basics/documents/create_many',
#  'http://fauna/current/learn/cookbook/fql/basics/documents/upsert',
#  'http://fauna/current/learn/cookbook/fql/basics/functions/',
#  'http://fauna/current/learn/cookbook/fql/basics/functions/call',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/functions/create',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/functions/delete',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/functions/get',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/functions/list',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/functions/metadata',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/functions/rename',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/create',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/delete',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/get',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/list',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/query',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/metadata',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/indexes/rename',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/keys/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/keys/create',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/keys/delete',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/keys/get',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/keys/list',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/keys/metadata',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/tokens/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/tokens/create',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/tokens/delete',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/tokens/get',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/tokens/list',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/basics/tokens/metadata',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/array/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/array/zip',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/math/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/math/unsigned_integer_subtraction',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/list_of_terms',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/missing_field_value',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/null_field',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/duplicate_values',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/udf-list_of_terms',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/search/search_range',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/strings/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/fql/strings/split',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/counter',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/sort',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/search_range',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/composable_types/',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/composable_types/single_type',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/composable_types/sparse_fields',
#  'https://docs.fauna.com/fauna/current/learn/cookbook/graphql/composable_types/component_pattern',
#  'https://docs.fauna.com/fauna/current/build/',
#  'https://docs.fauna.com/fauna/current/build/fql/',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/csharp',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/go',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/java',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/javascript',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/python',
#  'https://docs.fauna.com/fauna/current/build/fql/drivers/scala',
#  'https://docs.fauna.com/fauna/current/build/fql/crud',
#  'https://docs.fauna.com/fauna/current/build/fql/composition',
#  'https://docs.fauna.com/fauna/current/build/fql/types',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/terms',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/values',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/bindings',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/pagination',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/multi-collection',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/temporality',
#  'https://docs.fauna.com/fauna/current/build/fql/indexes/combining',
#  'https://docs.fauna.com/fauna/current/build/fql/udfs',
#  'https://docs.fauna.com/fauna/current/build/fql/temporality',
#  'https://docs.fauna.com/fauna/current/build/fql/errors',
#  'https://docs.fauna.com/fauna/current/build/best_practices/',
#  'https://docs.fauna.com/fauna/current/build/best_practices/performance',
#  'https://docs.fauna.com/fauna/current/build/best_practices/defensive_query',
#  'https://docs.fauna.com/fauna/current/build/best_practices/errors',
#  'https://docs.fauna.com/fauna/current/build/best_practices/indexes',
#  'https://docs.fauna.com/fauna/current/build/best_practices/security',
#  'https://docs.fauna.com/fauna/current/build/tools/',
#  'https://docs.fauna.com/fauna/current/build/tools/dashboard/',
#  'https://docs.fauna.com/fauna/current/build/tools/dashboard/mfa',
#  'https://docs.fauna.com/fauna/current/build/tools/dashboard/teams',
#  'https://docs.fauna.com/fauna/current/build/tools/dev',
#  'https://docs.fauna.com/fauna/current/build/tools/shell/',
#  'https://docs.fauna.com/fauna/current/build/tools/shell/config',
#  'https://docs.fauna.com/fauna/current/build/tools/shell/commands/',
#  'https://docs.fauna.com/fauna/current/build/tools/shell/commands/add-endpoint',
#  'https://docs.fauna.com/fauna/current/build/tools/shell/commands/autocomplete',
#  'https://docs.fauna.com/fauna/current/build/tools/shell/commands/cloud-login',
#  'http://example.com/fauna/current/build/tools/shell/commands/create-database',
#  'http://example.com/fauna/current/build/tools/shell/commands/create-key',
#  'http://example.com/fauna/current/build/tools/shell/commands/default-endpoint',
#  'http://example.com/fauna/current/build/tools/shell/commands/delete-database',
#  'http://example.com/fauna/current/build/tools/shell/commands/delete-endpoint',
#  'http://example.com/fauna/current/build/tools/shell/commands/delete-key',
#  'http://example.com/fauna/current/build/tools/shell/commands/eval',
#  'http://example.com/fauna/current/build/tools/shell/commands/help',
#  'http://example.com/fauna/current/build/tools/shell/commands/import',
#  'http://example.com/fauna/current/build/tools/shell/commands/list-databases',
#  'http://example.com/fauna/current/build/tools/shell/commands/list-endpoints',
#  'http://example.com/fauna/current/build/tools/shell/commands/list-keys',
#  'http://example.com/fauna/current/build/tools/shell/commands/shell',
#  'http://example.com/fauna/current/build/tools/shell/commands/upload-graphql-schema',
#  'http://example.com/fauna/current/build/tools/shell/login',
#  'http://example.com/fauna/current/build/tools/vs_code',
#  'http://example.com/fauna/current/build/logs/',
#  'http://example.com/fauna/current/build/logs/query_log/',
#  'http://example.com/fauna/current/build/logs/query_log/user_guide',
#  'http://example.com/fauna/current/build/logs/query_log/api_guide',
#  'http://example.com/fauna/current/build/logs/query_log/reference/',
#  'http://example.com/fauna/current/build/logs/query_log/reference/api_reference-0',
#  'http://example.com/fauna/current/build/logs/query_log/reference/api_reference-1',
#  'http://example.com/fauna/current/build/logs/query_log/reference/api_reference-2',
#  'http://example.com/fauna/current/build/logs/query_log/reference/api_reference-3',
#  'http://example.com/fauna/current/build/logs/query_log/reference/log_reference',
#  'http://example.com/fauna/current/build/integrations/',
#  'http://example.com/fauna/current/build/integrations/airbyte',
#  'https://docs.fauna.com/fauna/current/build/integrations/appsmith',
#  'https://docs.fauna.com/fauna/current/build/integrations/cloudflare',
#  'https://docs.fauna.com/fauna/current/build/integrations/fastly',
#  'https://docs.fauna.com/fauna/current/build/integrations/netlify',
#  'https://docs.fauna.com/fauna/current/build/integrations/retool',
#  'https://docs.fauna.com/fauna/current/build/integrations/vercel',
#  'https://docs.fauna.com/fauna/current/build/integrations/wundergraph',
#  'https://docs.fauna.com/fauna/current/api/',
#  'https://docs.fauna.com/fauna/current/api/graphql/',
#  'https://docs.fauna.com/fauna/current/api/graphql/endpoints',
#  'https://docs.fauna.com/fauna/current/api/graphql/errors',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_collection',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_embedded',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_generateudfresolvers',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_index',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_relation',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_resolver',
#  'https://docs.fauna.com/fauna/current/api/graphql/directives/d_unique',
#  'https://docs.fauna.com/fauna/current/api/graphql/schemas',
#  'https://docs.fauna.com/fauna/current/api/graphql/input',
#  'https://docs.fauna.com/fauna/current/api/graphql/relationships',
#  'https://docs.fauna.com/fauna/current/api/graphql/functions',
#  'https://docs.fauna.com/fauna/current/api/fql/',
#  'https://docs.fauna.com/fauna/current/api/fql/cheat_sheet',
#  'https://docs.fauna.com/fauna/current/api/fql/indexes',
#  'https://docs.fauna.com/fauna/current/api/fql/deprecations',
#  'https://docs.fauna.com/fauna/current/api/fql/known_issues',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/abort',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/abs',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/accessprovider',
#  'http://fauna/current/api/fql/functions/accessproviders',
#  'http://fauna/current/api/fql/functions/collection',
#  'http://fauna/current/api/fql/functions/collections',
#  'http://fauna/current/api/fql/functions/call',
#  'http://fauna/current/api/fql/functions/containsfield',
#  'http://fauna/current/api/fql/functions/containspath',
#  'http://fauna/current/api/fql/functions/containsstr',
#  'http://fauna/current/api/fql/functions/containsstrregex',
#  'http://fauna/current/api/fql/functions/containsvalue',
#  'http://fauna/current/api/fql/functions/create',
#  'http://fauna/current/api/fql/functions/createaccessprovider',
#  'http://fauna/current/api/fql/functions/createclass',
#  'http://fauna/current/api/fql/functions/createcollection',
#  'http://fauna/current/api/fql/functions/createdatabase',
#  'http://fauna/current/api/fql/functions/createfunction',
#  'http://fauna/current/api/fql/functions/createindex',
#  'http://fauna/current/api/fql/functions/createkey',
#  'http://fauna/current/api/fql/functions/createrole',
#  'http://fauna/current/api/fql/functions/credentials',
#  'http://fauna/current/api/fql/functions/currentidentity',
#  'http://fauna/current/api/fql/functions/currenttoken',
#  'http://fauna/current/api/fql/functions/database',
#  'http://fauna/current/api/fql/functions/databases',
#  'http://fauna/current/api/fql/functions/date',
#  'http://fauna/current/api/fql/functions/documents',
#  'http://fauna/current/api/fql/functions/drop',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/endswith',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/epoch',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/equals',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/events',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/exists',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/exp',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/filter',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/findstr',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/findstrregex',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/floor',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/foreach',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/format',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/function',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/functions',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/gt',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/gte',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/get',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/hascurrentidentity',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/hasidentity',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/hascurrenttoken',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/hour',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/hypot',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/identify',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/identity',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/if',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/iindex',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/indexes',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/insert',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/intersection',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isarray',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isboolean',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isbytes',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/iscollection',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/iscredentials',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isdatabase',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isdate',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isdoc',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isdouble',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isempty',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isfunction',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isindex',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isinteger',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/iskey',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/islambda',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isnonempty',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isnull',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isnumber',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isobject',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isref',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isrole',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isset',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/isstring',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/istimestamp',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/istoken',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/join',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/keyfromsecret',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/keys',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/lt',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/lte',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/ltrim',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/lambda',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/length',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/let',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/ln',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/log',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/login',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/logout',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/lowercase',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/map',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/match',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/max',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/mean',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/merge',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/min',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/minute',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/modulo',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/month',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/movedatabase',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/multiply',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/newid',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/not',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/now',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/or',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/paginate',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/pow',
#  'https://fauna.com/blog/build-a-blogging-engine-with-fauna-and-nextjs',
#  'https://docs.fauna.com/fauna/current/tutorials/blogging_engine',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/query',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/ref',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/remove',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/select',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/subtract',
#  'https://docs.fauna.com/fauna/current/api/fql/functions/prepend',
#  'https://fauna.com/blog/building-a-blog-with-fauna-db-and-nextjs',
#  'https://www.youtube.com/watch?v=KjJ6mRQY1CQ',
#  'https://www.freecodecamp.org/news/how-to-build-a-blog-with-fauna-db-and-nextjs/',
#  'https://fauna.com/drivers',
#  'https://fauna.com/security',
#  'https://fauna.com/references',
#  'https://forums.fauna.com/',
#  'https://www2.fauna.com/terms',
#  'https://www2.fauna.com/privacy']
